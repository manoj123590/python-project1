# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# # Dataset Information
# Dream Housing finance company deals in all home loans. They hava a presence accrounce all urban,semi urban,and rurals areas.
# Coustemer first appaly for home loan after that company validates the coustmer eligiblity for the loan. Company wants to automated
# the loan eligibility process (real time) based on the coustmer detail provided while filling online application form.

# %% [markdown]
# # Import Moduls

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib
# %mathplotlib inline
# Out:
# UsageError: Line magic function `%mathplotlib` not found.

# %% [markdown]
# # Loading the dataset

# %%
df= pd.read_csv("Desktop/Data Science proj 1/Loan Prediction Dataset.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %% [markdown]
# # Preprocessing the dataset

# %%
# find the null values
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
# fill the missing value from the numerical tearms-using mean
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
# fill the missing values for Catrogacial tearms-using mode()
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])
df['Married']=df['Married'].fillna(df['Married'].mode()[0])
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])
#df['Self_Employed ']=df['Self_Employed '].fillna(df['Self_Employed '].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
# catgerocial attrubites
sns.countplot(df['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
sns.countplot(df['Married'])
# Out:
# <Axes: xlabel='count', ylabel='Married'>

# %%
sns.countplot(df['Dependents'])
# Out:
# <Axes: xlabel='count', ylabel='Dependents'>

# %%
sns.countplot(df['Education'])
# Out:
# <Axes: xlabel='count', ylabel='Education'>

# %%
sns.countplot(df['Self_Employed'])
# Out:
# <Axes: xlabel='count', ylabel='Self_Employed'>

# %%
sns.countplot(df['Property_Area'])
# Out:
# <Axes: xlabel='count', ylabel='Property_Area'>

# %%
# Numirecial attrubits vizulation 
sns.distplot(df['ApplicantIncome'])
# Out:
# C:\Users\Rajaparthiban\AppData\Local\Temp\ipykernel_6964\4044073353.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
# APPLY log transformation to the attrubites 
df['ApplicantIncome']=np.log(df['ApplicantIncome'])
# Out:
# F:\python\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.displot(df['ApplicantIncome'])

# %%
sns.distplot(df['CoapplicantIncome'])
# Out:
# C:\Users\Rajaparthiban\AppData\Local\Temp\ipykernel_6964\2149142820.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CoapplicantIncome'])
# <Axes: xlabel='CoapplicantIncome', ylabel='Density'>

# %%
df['CoapplicantIncomelog']=np.log(df['CoapplicantIncome'])

# %%
sns.distplot(df['CoapplicantIncome'])
# Out:
# C:\Users\Rajaparthiban\AppData\Local\Temp\ipykernel_6964\2149142820.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CoapplicantIncome'])
# <Axes: xlabel='CoapplicantIncome', ylabel='Density'>

# %%
sns.displot(df['LoanAmount'])

# %%
df['LoanAmountLog']=np.log(df['LoanAmount'])
sns.displot(df['LoanAmountLog'])

# %%
sns.displot(df['Loan_Amount_Term'])

# %%
df['Loan_Amount_Term_Log']=np.log(df['Loan_Amount_Term'])
sns.displot(df['Loan_Amount_Term_Log'])

# %%
sns.displot(df['Credit_History'])

# %% [markdown]
# # creation of new attrubites

# %%
# total income
df['Total_Income']=df['ApplicantIncome']+df['CoapplicantIncome']
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         8.651724                NaN    4.700480          5.886104
# 1         8.031385           1.989684    4.836282          5.886104
# 2         8.517193           2.014308    5.337538          5.886104
# 3         7.757906           2.059529    4.605170          5.886104
# 4         8.094378                NaN    4.356709          5.886104
#
#    Credit_History Property_Area  Total_Income
# 0        0.000000         Urban           NaN
# 1        0.000000         Urban     10.021069
# ...

# %%
df['Total_Income_log']=np.log(df['Total_Income'])
sns.displot(['Total_Income_Log'])

# %% [markdown]
# # Coorelation Matrix

# %%
corr=df.corr(numeric_only=True)
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot= True,cmap="BuPu")
# Out:
# <Axes: >

# %%
print(df.columns.tolist())
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Total_Income', 'Loan_Amount_Term_Log', 'LoanAmountLog', 'CoapplicantIncomelog', 'Total_Income_Log', 'Total_Income_log']

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0         2.157759                NaN    4.700480          5.886104
# 1         2.083357           1.989684    4.836282          5.886104
# 2         2.142087           2.014308    5.337538          5.886104
# 3         2.048712           2.059529    4.605170          5.886104
# 4         2.091170                NaN    4.356709          5.886104
#
#    Credit_History Property_Area  Total_Income  Loan_Amount_Term_Log  \
# 0        0.000000         Urban           NaN              1.772594
# ...

# %%
# drop unnessary coulmns
cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Loan_ID']
df=df.drop(columns=cols,axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[250], line 3
#       1 # drop unnessary coulmns
#       2 cols=['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Loan_ID']
# ----> 3 df=df.drop(columns=cols,axis=1)
#       4 df.head()
#
# File F:\python\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
cols=['Gender','Married','Education','Self_Employed','Property_Area','Credit_History','Dependents']
le=LabelEncoder()
for col in cols:
    df[col]=le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  Credit_History  \
# 0       1        1          0          0              0               2
# 1       1        1          1          0              0               2
# 2       1        1          2          0              0               2
# 3       1        1          2          0              0               1
# 4       1        0          0          1              0               2
#
#    Property_Area  Total_Income  Loan_Amount_Term_Log  LoanAmountLog  \
# 0              2           NaN              1.772594       1.547665
# 1              2      2.304690              1.772594       1.576146
# 2              2      2.354371              1.772594       1.674765
# 3              2      2.284160              1.772594       1.527180
# 4              2           NaN              1.772594       1.471717
#
#    CoapplicantIncomelog  Total_Income_Log  Total_Income_log
# 0                   NaN               NaN               NaN
# ...

# %% [markdown]
# # Train-Test Split

# %%
#specify input and output attributs
x=df.drop(columns=['Total_Income_Log'],axis=1)
y=df['Total_Income_Log']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
sns.heatmap(x,annot=True)
# Out:
# <Axes: >
